# %% [markdown]
# ### Задание - апроксимировать данные с помощью метода линейной регрессии

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data.csv")

# %%
plt.scatter(data['x'], data['y'])
plt.title("Cool data")
plt.grid()

# %%
import sklearn

# Your Code Here
